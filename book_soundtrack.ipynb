# %% [markdown]
# **About**
# This was my final project at allWomen Tech DS Bootcamp (5/2021-7/2021). The video presentation can be seen here: https://youtu.be/Ke0LeeY-LK8?t=1367 and the presentations without narration can be seen here: https://sway.office.com/W0qWgUcxXmIMwpbV?ref=Link

# %% [markdown]
# **Next Steps**
# * Scrape track numbers from Spotify - either use fuzzy match to work with csv I have or scrape track info and combine csv files
# * Create a webapp so people can use this themselves
# * Allow users to sign into their own Spotify account to create their own playlists
# * Set up automatic scraping of books

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-all-the-things" data-toc-modified-id="Import-all-the-things-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import all the things</a></span></li><li><span><a href="#Read-csv-book-and-lyric-files" data-toc-modified-id="Read-csv-book-and-lyric-files-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Read csv book and lyric files</a></span><ul class="toc-item"><li><span><a href="#Rename-columns-to-match" data-toc-modified-id="Rename-columns-to-match-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Rename columns to match</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Check-for-nulls" data-toc-modified-id="Check-for-nulls-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Check for nulls</a></span></li><li><span><a href="#Check-for-duplicates-and-drop" data-toc-modified-id="Check-for-duplicates-and-drop-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Check for duplicates and drop</a></span></li><li><span><a href="#Preprocess-words-column" data-toc-modified-id="Preprocess-words-column-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Preprocess words column</a></span><ul class="toc-item"><li><span><a href="#There-are-a-few-irregularies-still,-so-let's-clean-those-up-too" data-toc-modified-id="There-are-a-few-irregularies-still,-so-let's-clean-those-up-too-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>There are a few irregularies still, so let's clean those up too</a></span></li></ul></li><li><span><a href="#Take-a-quick-peek-to-see-how-many-songs/books-each-artist-has" data-toc-modified-id="Take-a-quick-peek-to-see-how-many-songs/books-each-artist-has-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Take a quick peek to see how many songs/books each artist has</a></span></li></ul></li><li><span><a href="#Create-some-visualizations" data-toc-modified-id="Create-some-visualizations-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Create some visualizations</a></span><ul class="toc-item"><li><span><a href="#Wordclouds" data-toc-modified-id="Wordclouds-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Wordclouds</a></span><ul class="toc-item"><li><span><a href="#Book-Authors" data-toc-modified-id="Book-Authors-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Book Authors</a></span></li><li><span><a href="#Band-Names" data-toc-modified-id="Band-Names-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Band Names</a></span></li></ul></li><li><span><a href="#Bar-charts" data-toc-modified-id="Bar-charts-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Bar charts</a></span><ul class="toc-item"><li><span><a href="#Book-Authors" data-toc-modified-id="Book-Authors-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Book Authors</a></span></li><li><span><a href="#Band-Names" data-toc-modified-id="Band-Names-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Band Names</a></span></li></ul></li><li><span><a href="#Which-is-more-popular:-vampire,-shifter,-or-fae?" data-toc-modified-id="Which-is-more-popular:-vampire,-shifter,-or-fae?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Which is more popular: vampire, shifter, or fae?</a></span></li></ul></li><li><span><a href="#Join-the-datasets" data-toc-modified-id="Join-the-datasets-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Join the datasets</a></span><ul class="toc-item"><li><span><a href="#Check-the-sizes" data-toc-modified-id="Check-the-sizes-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Check the sizes</a></span></li><li><span><a href="#Count-the-most-common-words" data-toc-modified-id="Count-the-most-common-words-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Count the most common words</a></span><ul class="toc-item"><li><span><a href="#Create-a-word-cloud-of-the-words-(both-book-descriptions-and-lyrics)" data-toc-modified-id="Create-a-word-cloud-of-the-words-(both-book-descriptions-and-lyrics)-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Create a word cloud of the words (both book descriptions and lyrics)</a></span></li></ul></li></ul></li><li><span><a href="#Build-System" data-toc-modified-id="Build-System-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Build System</a></span><ul class="toc-item"><li><span><a href="#Vectorize-and-find-cosine-similarities" data-toc-modified-id="Vectorize-and-find-cosine-similarities-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Vectorize and find cosine similarities</a></span></li><li><span><a href="#Recommender-function" data-toc-modified-id="Recommender-function-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Recommender function</a></span></li><li><span><a href="#RUN-IT---WOOT-WOOT" data-toc-modified-id="RUN-IT---WOOT-WOOT-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>RUN IT - WOOT WOOT</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Import all the things

# %%
import pandas as pd 
import numpy as np
import json
 
# text processing libraries
import re
import string
import nltk
#nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

from collections import Counter

# sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics.pairwise import sigmoid_kernel
from sklearn.neighbors import NearestNeighbors

#plotting
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import plotly.express as px
from matplotlib.colors import Normalize

from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
import sys

sys.path.insert(0, r"functions")
from myEDA import *
from text_functions import *

# %% [markdown]
# # Read csv book and lyric files

# %%
ldf = pd.read_csv(r"datasets\lyrics_raw.csv", index_col = 0, na_values = ' ')
ldf.tail()
# Out:
#       artist                               title  \
# 3126  Winger                 Under One Condition
# 3127  Winger                       Who's The One
# 3128  Winger                   Without the Night
# 3129  Winger                             Witness
# 3130  Winger  You Are The Saint, I Am The Sinner
#
#                                                   words  format
# 3126  She's looking in the eye of a Mind made up tha...       1
# 3127  -------------------- When all the colors begin...       1
# 3128  Watch the sun go down It's just my luck again ...       1
# 3129  There's a shadow in your heart Keeps you in th...       1
# 3130  You Are The Saint, I Am The Sinner (3: 35) (Wi...       1

# %%
bdf = pd.read_csv(r"datasets\books_raw.csv", index_col = 0, na_values = ' ')
bdf.head()
# Out:
#            author                          title  \
# 0  Shannon Delany                     13 to Life
# 1     Jamie Ayres                      18 Things
# 2  Jocelyn Davies               A Beautiful Dark
# 3    Lynsay Sands             A Bite to Remember
# 4  Veronica Blade  A Bite's Tale (A Furry Fable)
#
#                                                 desc  format
# 0  Everything about Jessie Gillmansen’s life chan...       0
# 1  Olga Gay Worontzoff thinks her biggest problem...       0
# 2  On the night of Skye’s seventeenth birthday, s...       0
# 3  Rule #1: Never get involved with someone who w...       0
# 4  A Cinderella who spends her nights as a wolf. ...       0

# %% [markdown]
# ## Rename columns to match

# %%
ldf = ldf.rename(columns={"band": "artist", "lyrics": "words", "song": "title"})
ldf.shape
# Out:
# (3131, 4)

# %%
bdf = bdf.rename(columns={"author": "artist", "desc": "words"})
bdf.shape
# Out:
# (2944, 4)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Check for nulls

# %%
bdf.isna().sum()
# Out:
# artist    0
# title     0
# words     0
# format    0
# dtype: int64

# %%
ldf.isna().sum()
# Out:
# artist    0
# title     0
# words     0
# format    0
# dtype: int64

# %% [markdown]
# ## Check for duplicates and drop

# %%
bdf.duplicated().value_counts()
# Out:
# False    2944
# dtype: int64

# %%
ldf.duplicated().value_counts()
# Out:
# False    3131
# dtype: int64

# %%
bdf.drop_duplicates(keep = 'first', inplace = True)
bdf.shape
# Out:
# (2944, 4)

# %% [markdown]
# ## Preprocess words column

# %%
ldf = clean_data(ldf, ['words'])
bdf = clean_data(bdf, ['words'])
# Out:
# Data cleaning started........
# Data cleaning Done........
# Data cleaning started........
# Data cleaning Done........

# %% [markdown]
# ### There are a few irregularies still, so let's clean those up too

# %%
bdf.replace('embedshare','',regex=True,inplace=True)
bdf.replace('copyembed','',regex=True,inplace=True)
bdf.replace('embedcopy','',regex=True,inplace=True)
bdf.replace('urlcopy','',regex=True,inplace=True)
bdf.replace('copy','',regex=True,inplace=True)

# %% [markdown]
# ## Take a quick peek to see how many songs/books each artist has

# %%
num_of_songs = ldf['artist'].value_counts()
num_of_songs
# Out:
# Van Halen                  102
# Stryper                    100
# Great White                 98
# W.A.S.P.                    98
# Whitesnake                  97
# Bon Jovi                    96
# Warrant                     95
# Kiss                        94
# Scorpions                   93
# Tesla                       92
# L.A. Guns                   90
# House of Lords              88
# Twisted Sister              88
# Mötley Crüe                 85
# Dokken                      83
# Def Leppard                 82
# Europe                      80
# Poison                      79
# Queensrÿche                 77
# Guns N' Roses               76
# Mr. Big                     74
# Ratt                        71
# Hanoi Rocks                 66
# Lita Ford                   59
# Winger                      57
# Jackyl                      56
# Extreme                     56
# White Lion                  52
# Firehouse                   51
# Loverboy                    51
# ...

# %%
num_of_books = bdf['artist'].value_counts()
num_of_books
# Out:
# Sherrilyn Kenyon                                                          40
# Bella Forrest                                                             38
# Christine Feehan                                                          36
# Gena Showalter                                                            33
# L.J. Smith                                                                28
#                                                                           ..
# Selena Kitt                                                                1
# Laini Taylor|Montserrat Nieto                                              1
# Hannah Howell|Lynsay Sands|Sara Blayne|Kate Huntington|Richard  Newton     1
# Kim Harrison|Lynsay Sands|Marjorie M. Liu|Vicki Pettersson                 1
# Eiri Kaji|舵 英里                                                             1
# Name: artist, Length: 1168, dtype: int64

# %% [markdown]
# # Create some visualizations

# %% [markdown]
# ## Wordclouds

# %% [markdown]
# ### Book Authors

# %%
#Explode the authors so there's one per cell
bdf_ex = (bdf.artist.str.split('|', expand=True)
             .stack()
             .reset_index(level=1, drop=True))

# %%
#Count the number of authors
#This allows author names with more than 2 strings - L.J. Smith for example
num_of_books = bdf_ex.value_counts()
bdf_dict = dict(num_of_books)
#bdf_dict

# %%
b_img = np.array(Image.open('lovelib.jpg'))
#image_colours = ImageColorGenerator(b_img)

book_wc = WordCloud(background_color='black',
                    width=1500,
                    height=1000, 
                    mask = b_img,
                    colormap="Spectral",
                    contour_width=.05,
                    contour_color='red'
                    ).generate_from_frequencies(bdf_dict)

plt.figure(figsize=(11,7))
plt.imshow(book_wc)
plt.axis('off')
plt.show()

book_wc.to_file('book_wc.png')

# %% [markdown]
# ### Band Names

# %%
num_of_songs = ldf['artist'].value_counts()
ldf_dict = dict(num_of_songs)
#ldf_dict

# %%
l_img = np.array(Image.open('guitar.jpg'))

song_wc = WordCloud(background_color='black',
                      mask = l_img,
                      min_font_size = 4,
                      colormap="Reds",
                      contour_width=.1, 
                      contour_color='Red'
                      ).generate_from_frequencies(ldf_dict)


plt.figure(figsize=(11,9))
plt.imshow(song_wc)
plt.axis('off')
plt.show()

song_wc.to_file('song_wc.png')

# %% [markdown]
# ## Bar charts

# %% [markdown]
# ### Book Authors

# %%
#get 20 authors with the most books
books_by_authors = bdf_ex.value_counts()[:20]
#plot simple bar chart
books_by_authors.plot(kind='bar')

books_by_authors.to_csv("books_by_author.csv")

# %% [markdown]
# ### Band Names

# %%
#get 20 bands with the most songs
songs_by_band = ldf['artist'].value_counts()[:20]

#plot a simple bar chart
songs_by_band.plot(kind='bar')

songs_by_band.to_csv("songs_by_band.csv")

# %% [markdown]
# ## Which is more popular: vampire, shifter, or fae?

# %%
#Find the number of rows that contain the keywords
count1 = bdf['words'].str.contains('vampire').sum()
count2 = bdf['words'].str.contains('shifter|wolf|pack').sum()
count3 = bdf['words'].str.contains('fairy|fae').sum()

#create a dictionary from keywords and counts
monster_dict = {'Vampire': count1, 'Shifter':count2, 'Fae':count3}
monster_dict
# Out:
# {'Vampire': 691, 'Shifter': 474, 'Fae': 134}

# %%
#plot simple bar chart
plt.bar(range(len(monster_dict)), monster_dict.values(), align='center')
plt.xticks(range(len(monster_dict)), list(monster_dict.keys()))
plt.show()

# %% [markdown]
# # Join the datasets

# %%
df = pd.concat([bdf, ldf]).reset_index(drop = True)
df.shape
# Out:
# (6075, 4)

# %%
df.replace('embedshare','',regex=True,inplace=True)
df.replace('copyembed','',regex=True,inplace=True)
df.replace('embedcopy','',regex=True,inplace=True)
df.replace('urlcopy','',regex=True,inplace=True)
df.replace('copy','',regex=True,inplace=True)

# %% [markdown]
# ## Check the sizes

# %%
x=df['format'].value_counts()
print(x)
sns.barplot(x.index,x)
# Out:
# 1    3131
# 0    2944
# Name: format, dtype: int64
# <AxesSubplot:ylabel='format'>

# %% [markdown]
# ## Count the most common words

# %%
vocab = Counter()

for lines in df["words"]:
    for word in lines.split(' '):
        vocab[word] += 1

voc_mc = vocab.most_common(200)
voc_dict = dict(voc_mc)

# %% [markdown]
# ### Create a word cloud of the words (both book descriptions and lyrics)

# %%
wordcloud = WordCloud(background_color='black',
                      min_font_size = 4,
                      colormap="spring"
                      ).generate_from_frequencies(voc_dict)


plt.figure(figsize=(11,9))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Build System

# %% [markdown]
# ## Vectorize and find cosine similarities

# %%
tfidf = TfidfVectorizer(stop_words='english')

# %%
tfidf_matrix = tfidf.fit_transform(df['words'])
tfidf_matrix.shape
# Out:
# (6075, 29660)

# %%
# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
#Construct a reverse mapping of indices and titles
indices = pd.Series(df.index, index=df['title'])

# %% [markdown]
# ## Recommender function

# %%
def content_recommender(title, cosine_sim=cosine_sim, df=df, indices=indices):
    
    #find the index number of the first song
    ind_num = df.query('format == 1').index.tolist()
    
    # Obtain the index of the book that matches the title
    idx = indices[title]
    print(idx)

    # Get the pairwsie similarity scores of all books and songs
    # And convert it into a list of tuples as described above
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort  based on the cosine similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the top matches (books and songs)
    sim_scores = sim_scores[1:500]

    # Get the indices
    #Loop through the top 50 matches and pull out only the songs
    title_indices = [i[0] for i in sim_scores if i[0] > ind_num[0]]
    
    #Get the top 20 songs
    title_indices = title_indices[0:20]

    # Return the top 10 most similar titles
    return df[['title', 'artist']].iloc[title_indices]

# %% [markdown]
# ## RUN IT - WOOT WOOT

# %%
btitle = 'Dead Until Dark'
content_recommender(btitle)
# Out:
# 702
#                                    title       artist
# 3066            Speedin' Back to My Baby         Kiss
# 3517                        In My Dreams       Dokken
# 5055                            The Show   BulletBoys
# 3348  My Girlfriend's Boyfriend Isn't Me    Autograph
# 4307                         Blind Faith       Poison
# 4877                  Walks Like a Woman  Baton Rouge
# 3881                       Maybe Someday  Great White
# 4349                       Shooting Star       Poison
# 3062              See You in Your Dreams         Kiss
# 5342                     Together as One      Stryper
# 3619               Always the Pretenders       Europe
# 4594                  When You Were Mine  Saigon Kick
# 3126                      Russian Winter       Krokus
# 3617                      A Mother's Son       Europe
# 3636                   Girl from Lebanon       Europe
# 5241                           Time's Up    Love/Hate
# ...
